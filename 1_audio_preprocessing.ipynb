# %%
# 녹음된 음성 데이터를 전처리하는 과정입니다.
# 녹음된 음성데이터는 비트메이트_TP01/data/dataset/wav_{speaker}/raw폴더에 있어야합니다.
# raw 폴더 내 음성데이터를 변환해서 wavs 폴더에 저장합니다.

# .m4a .wav 상관 없이 .wav 로 변환해줍니다.
# samplingrate는 24000으로 변경합니다. (finetunning시 24000으로 학습시켜야함)
# 무음 구간은 제거합니다
# 볼륨도 일정하게 조절합니다.

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
from pathlib import Path
import numpy as np
import librosa
import soundfile as sf

# =========================
# 경로 설정
# =========================
SPEAKER = "jjy"

BASE_DIR = Path("/content/drive/MyDrive/비트메이트_TP01")
DATASET_DIR = BASE_DIR / "data" / "dataset" / f"wav_{SPEAKER}"

INPUT_DIR = DATASET_DIR / "raw"
OUTPUT_DIR = DATASET_DIR / "wavs"

OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

TARGET_SR = 24000

# =========================
# 파일 리스트
# =========================
audio_files = [
    p for p in INPUT_DIR.iterdir()
    if p.suffix.lower() in [".wav", ".m4a"]
]

if not audio_files:
    raise RuntimeError(f"오디오 파일 없음: {INPUT_DIR}")

print(f"총 파일 수: {len(audio_files)}")

# =========================
# 전처리
# =========================
for input_path in audio_files:
    output_path = OUTPUT_DIR / (input_path.stem + ".wav")

    try:
        # 1. 로드 + mono + resample
        audio, sr = librosa.load(
            str(input_path),
            sr=TARGET_SR,
            mono=True
        )

        # 2. 무음 제거 (앞뒤)
        audio, _ = librosa.effects.trim(
            audio,
            top_db=30
        )

        # 3. normalize (볼륨 일정)
        max_val = np.max(np.abs(audio))
        if max_val > 0:
            audio = audio / max_val

        # 4. 너무 짧은 음성 제거 (노이즈 방지)
        if len(audio) < TARGET_SR * 0.3:  # 0.3초 이하 컷
            print(f"[스킵] 너무 짧음: {input_path.name}")
            continue

        # 5. 저장
        sf.write(str(output_path), audio, TARGET_SR)

        print(f"[완료] {input_path.name} → {output_path.name}")

    except Exception as e:
        print(f"[에러] {input_path.name}: {e}")
# Out:
# 총 파일 수: 85
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_002.m4a → audio_002.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_003.m4a → audio_003.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_004.m4a → audio_004.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_005.m4a → audio_005.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_006.m4a → audio_006.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_007.m4a → audio_007.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_008.m4a → audio_008.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_009.m4a → audio_009.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_010.m4a → audio_010.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_011.m4a → audio_011.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_012.m4a → audio_012.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_013.m4a → audio_013.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_014.m4a → audio_014.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_015.m4a → audio_015.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_016.m4a → audio_016.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_017.m4a → audio_017.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_018.m4a → audio_018.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_019.m4a → audio_019.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_020.m4a → audio_020.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_021.m4a → audio_021.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_022.m4a → audio_022.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_023.m4a → audio_023.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_024.m4a → audio_024.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_025.m4a → audio_025.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_026.m4a → audio_026.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_027.m4a → audio_027.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_028.m4a → audio_028.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_029.m4a → audio_029.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_030.m4a → audio_030.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_031.m4a → audio_031.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_032.m4a → audio_032.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_033.m4a → audio_033.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_034.m4a → audio_034.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_035.m4a → audio_035.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_036.m4a → audio_036.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_037.m4a → audio_037.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_038.m4a → audio_038.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_039.m4a → audio_039.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_040.m4a → audio_040.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_041.m4a → audio_041.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_042.m4a → audio_042.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_043.m4a → audio_043.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_044.m4a → audio_044.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_045.m4a → audio_045.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_046.m4a → audio_046.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_047.m4a → audio_047.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_048.m4a → audio_048.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_049.m4a → audio_049.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_050.m4a → audio_050.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_051.m4a → audio_051.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_052.m4a → audio_052.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_053.m4a → audio_053.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_054.m4a → audio_054.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_055.m4a → audio_055.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_056.m4a → audio_056.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_057.m4a → audio_057.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_058.m4a → audio_058.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_059.m4a → audio_059.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_060.m4a → audio_060.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_061.m4a → audio_061.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_062.m4a → audio_062.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_063.m4a → audio_063.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_064.m4a → audio_064.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_065.m4a → audio_065.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_066.m4a → audio_066.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_067.m4a → audio_067.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_068.m4a → audio_068.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_069.m4a → audio_069.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_070.m4a → audio_070.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_071.m4a → audio_071.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_072.m4a → audio_072.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_073.m4a → audio_073.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_074.m4a → audio_074.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_075.m4a → audio_075.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_076.m4a → audio_076.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_077.m4a → audio_077.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_078.m4a → audio_078.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_079.m4a → audio_079.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_080.m4a → audio_080.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_081.m4a → audio_081.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_082.m4a → audio_082.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_083.m4a → audio_083.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_084.m4a → audio_084.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [완료] audio_085.m4a → audio_085.wav
# [완료] audio_001.m4a → audio_001.wav
# /tmp/ipykernel_567/3559004680.py:42: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)

# %%
import shutil

# =========================
# ref.wav 생성
# =========================
wavs = sorted([
    p for p in OUTPUT_DIR.iterdir()
    if p.suffix == ".wav"
])

if not wavs:
    raise RuntimeError(f"wavs 폴더에 파일 없음: {OUTPUT_DIR}")

ref_path = DATASET_DIR / "ref.wav"
# 길이 가장 긴 파일을 ref로 사용
source_audio = max(wavs, key=lambda p: p.stat().st_size)

# 덮어쓰기 복사
shutil.copy2(source_audio, ref_path)

print("ref.wav 생성 완료")
print("source:", source_audio.name)
print("target:", ref_path)
# Out:
# ref.wav 생성 완료
# source: audio_082.wav
# target: /content/drive/MyDrive/비트메이트_TP01/data/dataset/wav_jjy/ref.wav
